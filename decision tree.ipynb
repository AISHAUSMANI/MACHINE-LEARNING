# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 145            0      102             75             23        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 145                     0.572   21        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# !pip install skimpy
# Out:
# Requirement already satisfied: skimpy in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (0.0.14)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (2.15.1)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (8.1.7)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (6.28.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (2.1.4)
# Requirement already satisfied: polars<0.21,>=0.19 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (0.20.25)
# Requirement already satisfied: pyarrow<16,>=13 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (14.0.2)
# Requirement already satisfied: quartodoc<0.8.0,>=0.7.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (0.7.2)
# Requirement already satisfied: rich<14.0,>=10.9 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (13.3.5)
# Requirement already satisfied: typeguard==4.1.5 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from skimpy) (4.1.5)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from typeguard==4.1.5->skimpy) (4.9.0)
# Requirement already satisfied: colorama in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from click<9.0.0,>=8.1.6->skimpy) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.0)
# Requirement already satisfied: packaging in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.1)
# Requirement already satisfied: psutil in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Requirement already satisfied: griffe>=0.33 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (0.44.0)
# Requirement already satisfied: sphobjinv>=2.3.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (2.3.1)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (0.9.0)
# Requirement already satisfied: importlib-metadata>=5.1.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (7.0.1)
# Requirement already satisfied: importlib-resources>=5.10.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (6.4.0)
# Requirement already satisfied: pydantic in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (1.10.12)
# Requirement already satisfied: pyyaml in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (6.0.1)
# Requirement already satisfied: watchdog>=3.0.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (4.0.0)
# Requirement already satisfied: plum-dispatch>2.0.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from quartodoc<0.8.0,>=0.7.2->skimpy) (2.3.5)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from rich<14.0,>=10.9->skimpy) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from importlib-metadata>=5.1.0->quartodoc<0.8.0,>=0.7.2->skimpy) (3.17.0)
# Requirement already satisfied: decorator in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (305.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.0)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from plum-dispatch>2.0.0->quartodoc<0.8.0,>=0.7.2->skimpy) (0.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: attrs>=19.2 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (23.1.0)
# Requirement already satisfied: certifi in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (2024.2.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (4.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jsonschema>=3.0->sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jsonschema>=3.0->sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from jsonschema>=3.0->sphobjinv>=2.3.1->quartodoc<0.8.0,>=0.7.2->skimpy) (0.10.6)
# Requirement already satisfied: wcwidth in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: executing in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)

# %%
import skimpy as sk

# %%
sk.skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 768    │ │ int32       │ 7     │                                                          │
# │ │ Number of columns │ 9      │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name              ┃ NA  ┃ NA %   ┃ mean  ┃ sd    ┃ p0      ┃ p25   ┃ p50   ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ Pregnancies              │   0 │      0 │   3.8 │   3.4 │       0 │     1 │     3 │     6 │    17 │  ▇▅▃▁  │  │
# │ │ Glucose                  │   0 │      0 │   120 │    32 │       0 │    99 │   120 │   140 │   200 │   ▅▇▃▂ │  │
# │ │ BloodPressure            │   0 │      0 │    69 │    19 │       0 │    62 │    72 │    80 │   120 │ ▁ ▂▇▃  │  │
# │ │ SkinThickness            │   0 │      0 │    21 │    16 │       0 │     0 │    23 │    32 │    99 │  ▇▇▅   │  │
# │ │ Insulin                  │   0 │      0 │    80 │   120 │       0 │     0 │    30 │   130 │   850 │   ▇▂   │  │
# │ │ BMI                      │   0 │      0 │    32 │   7.9 │       0 │    27 │    32 │    37 │    67 │  ▁▇▆▁  │  │
# │ │ DiabetesPedigreeFunction │   0 │      0 │  0.47 │  0.33 │   0.078 │  0.24 │  0.37 │  0.63 │   2.4 │  ▇▃▁   │  │
# │ │ Age                      │   0 │      0 │    33 │    12 │      21 │    24 │    29 │    41 │    81 │  ▇▃▂▁  │  │
# │ │ Outcome                  │   0 │      0 │  0.35 │  0.48 │       0 │     0 │     0 │     1 │     1 │ ▇    ▅ │  │
# │ └──────────────────────────┴─────┴────────┴───────┴───────┴─────────┴───────┴───────┴───────┴───────┴────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1:]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 618            9      112             82             24        0  28.2
# 346            1      139             46             19       83  28.7
# 294            0      161             50              0        0  21.9
# 231            6      134             80             37      370  46.2
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# 346                     0.654   22
# 294                     0.254   65
# 231                     0.238   46
# ..                        ...  ...
# 71                      0.411   26
# 106                     0.207   27
# 270                     1.136   38
# 435                     0.205   29
# 102                     0.262   21
#
# [614 rows x 8 columns]

# %%
y_train
# Out:
#      Outcome
# 60         0
# 618        1
# 346        0
# 294        0
# 231        1
# ..       ...
# 71         0
# 106        0
# 270        1
# 435        1
# 102        0
#
# [614 rows x 1 columns]

# %%
df = DecisionTreeClassifier(criterion="entropy",max_depth=3)
df = df.fit(x_train,y_train)
y_pred = df.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7662337662337663

# %%
print('Accuracy Score: ', accuracy_score(y_test, y_pred))
print('Recall Score: ', recall_score(y_test, y_pred))
print('Precision Score: ', precision_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))
print('Confusion Matrix: \n', confusion_matrix(y_test, y_pred))
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Accuracy Score:  0.7662337662337663
# Recall Score:  0.6363636363636364
# Precision Score:  0.6862745098039216
# F1 Score:  0.660377358490566
# Confusion Matrix:
#  [[83 16]
#  [20 35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82        99
#            1       0.69      0.64      0.66        55
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.74      0.74       154
# weighted avg       0.76      0.77      0.76       154

# %%
# plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(95.72222222222221, 0.5, 'Actual')

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\lab4\anaconda3\anaconda raheen\lib\site-packages (from pydotplus) (3.0.9)

# %%
import pydotplus
